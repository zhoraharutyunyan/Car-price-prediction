# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
df_train
# Out:
#       model  year  motor_type  color  type  status  motor_volume  price
# 0         4  2022           3     15     5       1           2.0  24500
# 1         2  2014           3      1     5       1           2.0  25500
# 2         1  2018           3     10     5       1           2.0  11700
# 3         2  2002           3      6     5       1           3.2  12000
# 4         2  2017           3      1     5       2           2.0  26000
# ...     ...   ...         ...    ...   ...     ...           ...    ...
# 1637      0  2017           3     16     5       2           2.0  12400
# 1638      4  2014           3      1     5       2           2.0  16500
# 1639      3  2018           3      2     6       2           2.0  19500
# 1640      3  2019           3      1     6       1           2.0  19500
# 1641      4  2022           3     16     5       1           2.0  28500
#
# [1642 rows x 8 columns]

# %%
df_test
# Out:
#      model  year  motor_type  color  type  status  motor_volume
# 0        1  2020           3      1     5       1           2.0
# 1        3  2017           3     16     6       1           2.0
# 2        0  2021           3     16     5       1           2.0
# 3        1  2018           3     14     5       1           2.0
# 4        2  2003           3      1     1       4           1.8
# ..     ...   ...         ...    ...   ...     ...           ...
# 406      3  2021           3      1     6       1           2.0
# 407      0  2017           3     10     5       1           2.0
# 408      2  2012           3     16     5       2           2.0
# 409      1  2020           3     13     5       2           2.0
# 410      0  2017           3     16     5       1           2.0
#
# [411 rows x 7 columns]

# %%
df_test = df_test.drop('Id', axis=1)

# %%
df_train.isna().sum()[df_train.isna().sum() != 0].sort_values()[::-1] * 100 / len(df_train)
# Out:
# Series([], dtype: float64)

# %%
df_test.isna().sum()[df_test.isna().sum() != 0].sort_values()[::-1] * 100 / len(df_train)
# Out:
# Series([], dtype: float64)

# %%
set(df_test['model'].unique()).difference(set(df_train['model'].unique()))
# Out:
# set()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label = LabelEncoder()

# %%
df_train['model'] = label.fit_transform(df_train['model'])
df_test['model'] = label.transform(df_test['model'])

# %%
set(df_test['motor_type'].unique()).difference(set(df_train['motor_type'].unique()))
# Out:
# set()

# %%
df_train['motor_type'] = label.fit_transform(df_train['motor_type'])
df_test['motor_type'] = label.transform(df_test['motor_type'])

# %%
set(df_test['running'].unique()).difference(set(df_train['running'].unique()))
# Out:
# {'100500  km',
#  '103640  miles',
#  '105  km',
#  '114000  miles',
#  '118  miles',
#  '119700  km',
#  '12000  miles',
#  '122000  km',
#  '126405  miles',
#  '1300  miles',
#  '13500  km',
#  '1352  miles',
#  '13600  km',
#  '136879  km',
#  '137600  km',
#  '140500  miles',
#  '149000  miles',
#  '158000  km',
#  '163000  miles',
#  '164807  km',
#  '16800  km',
#  '169000  miles',
#  '172000  km',
#  '184000  km',
#  '19000  km',
#  '19365  miles',
#  '195000  km',
#  '197500  km',
#  '203500  km',
#  '2053  miles',
#  '211  km',
#  '218000  km',
#  '21850  miles',
#  '22400  miles',
#  '22500  km',
#  '226000  km',
#  '25000  km',
#  '250000  miles',
#  '25300  miles',
#  '25311  miles',
#  '258  km',
#  '26500  miles',
#  '27500  miles',
#  '295000  km',
#  '298000  km',
#  '30  miles',
#  '30700  miles',
#  '31500  km',
#  '32900  miles',
#  '33300  km',
#  '333000  km',
#  '33400  km',
#  '33700  miles',
#  '34200  miles',
#  '34598  miles',
#  '35400  km',
# ...

# %%
df_train = df_train.drop('running', axis=1)
df_test = df_test.drop('running', axis=1)

# %%
set(df_test['wheel'].unique()).difference(set(df_train['wheel'].unique()))
# Out:
# {'right'}

# %%
df_test['wheel'].unique()
# Out:
# array(['left', 'right'], dtype=object)

# %%
df_train['wheel'].unique()
# Out:
# array(['left'], dtype=object)

# %%
df_train = df_train.drop('wheel', axis=1)
df_test = df_test.drop('wheel', axis=1)

# %%
set(df_test['color'].unique()).difference(set(df_train['color'].unique()))
# Out:
# set()

# %%
df_train['color'] = label.fit_transform(df_train['color'])
df_test['color'] = label.transform(df_test['color'])

# %%
set(df_test['type'].unique()).difference(set(df_train['type'].unique()))
# Out:
# set()

# %%
df_train['type'] = label.fit_transform(df_train['type'])
df_test['type'] = label.transform(df_test['type'])

# %%
set(df_test['status'].unique()).difference(set(df_train['status'].unique()))
# Out:
# set()

# %%
df_train['status'] = label.fit_transform(df_train['status'])
df_test['status'] = label.transform(df_test['status'])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train = df_train.drop("price", axis=1)
y_train = df_train['price']

# %%
X_test = df_test.copy()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier()

# %%
params = {
    'n_estimators':[1],
    'criterion':['gini', 'entropy', 'log_loss'],
    'max_depth':[1]
}

# %%
final_model = GridSearchCV(model, param_grid=params, cv=3, verbose=2)

# %%
final_model.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# [CV] END ........criterion=gini, max_depth=1, n_estimators=1; total time=   0.0s
# [CV] END ........criterion=gini, max_depth=1, n_estimators=1; total time=   0.0s
# [CV] END ........criterion=gini, max_depth=1, n_estimators=1; total time=   0.0s
# [CV] END .....criterion=entropy, max_depth=1, n_estimators=1; total time=   0.0s
# [CV] END .....criterion=entropy, max_depth=1, n_estimators=1; total time=   0.0s
# [CV] END .....criterion=entropy, max_depth=1, n_estimators=1; total time=   0.0s
# [CV] END ....criterion=log_loss, max_depth=1, n_estimators=1; total time=   0.0s
# [CV] END ....criterion=log_loss, max_depth=1, n_estimators=1; total time=   0.0s
# [CV] END ....criterion=log_loss, max_depth=1, n_estimators=1; total time=   0.0s
# C:\Users\USER1\Desktop\ML_lesson\venv\Lib\site-packages\sklearn\model_selection\_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
# ...

# %%
y_pred = final_model.predict(X_test)

# %%
df_sub=pd.read_csv('sample_submission.csv')

# %%
df_sub
# Out:
#       Id  price
# 0      0     38
# 1      1  20549
# 2      2   3927
# 3      3   5572
# 4      4  28598
# ..   ...    ...
# 406  406   2514
# 407  407  20307
# 408  408  27274
# 409  409  14422
# 410  410   9376
#
# [411 rows x 2 columns]

# %%
df_sub['price']=y_pred

# %%
df_sub.to_csv('sub.csv',index = False,index_label=False)

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import AdaBoostClassifier

# %%
model = AdaBoostClassifier()

# %%
params = {
    'n_estimators':[50, 64, 80, 100],
    'learning_rate':[0.001, 0.01, 0.1, 1]
}

# %%
final_model = GridSearchCV(model, param_grid=params, cv=3, verbose=2)

# %%
final_model.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# C:\Users\USER1\Desktop\ML_lesson\venv\Lib\site-packages\sklearn\model_selection\_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   warnings.warn(
# [CV] END ...............learning_rate=0.001, n_estimators=50; total time=   0.1s
# [CV] END ...............learning_rate=0.001, n_estimators=50; total time=   0.1s
# [CV] END ...............learning_rate=0.001, n_estimators=50; total time=   0.1s
# [CV] END ...............learning_rate=0.001, n_estimators=64; total time=   0.1s
# [CV] END ...............learning_rate=0.001, n_estimators=64; total time=   0.1s
# [CV] END ...............learning_rate=0.001, n_estimators=64; total time=   0.2s
# [CV] END ...............learning_rate=0.001, n_estimators=80; total time=   0.2s
# [CV] END ...............learning_rate=0.001, n_estimators=80; total time=   0.2s
# ...

# %%
y_pred = final_model.predict(X_test)

# %%
df_sub=pd.read_csv('sample_submission.csv')

# %%
df_sub
# Out:
#       Id  price
# 0      0     38
# 1      1  20549
# 2      2   3927
# 3      3   5572
# 4      4  28598
# ..   ...    ...
# 406  406   2514
# 407  407  20307
# 408  408  27274
# 409  409  14422
# 410  410   9376
#
# [411 rows x 2 columns]

# %%
df_sub['price']=y_pred

# %%
df_sub.to_csv('sub1.csv',index = False,index_label=False)
